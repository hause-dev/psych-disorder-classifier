# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Load in Files

# %%
df = pd.read_csv('../Data/Results/Logisticregression_Maindisorder_Average_AUC.csv')
AEI = pd.read_csv('../Data/Results/Logisticregression_Maindisorder_AEI_AUC.csv')
model = pd.read_csv('../Data/Results/Main_Model_Average_AUC.csv')
sp = pd.read_csv('../Data/Results/Specific_Model_Average_AUC.csv')
splg = pd.read_csv('../Data/Results/Logisticregression_Specificdisorder_Average_AUC.csv')

# %% [markdown]
# ## Plot AUCs for No PCA vs PCA

# %% [markdown]
# #### This creates a line plot for the average AUC values of logistic regression for each main disorder, for both the models trained on PCA and without. The standard deviations of the AUCs are the error bars.

# %%
disorders = df.columns[1:]  # skip the first column
x = np.arange(len(disorders))

# Extract rows
without_pca = df.iloc[0, 1:].astype(float)
with_pca = df.iloc[1, 1:].astype(float)
std_without = df.iloc[2, 1:].astype(float)
std_with = df.iloc[3, 1:].astype(float)

# Plot with error bars
plt.figure(figsize=(10, 6))
plt.errorbar(x, without_pca, yerr=std_without, label='Without PCA', 
             marker='o', capsize=5, linestyle='-', color='darkred')
plt.errorbar(x, with_pca, yerr=std_with, label='With PCA', 
             marker='o', capsize=5, linestyle='-', color='midnightblue')

# Final touches
plt.xticks(x, disorders, rotation=45, ha='right', fontsize=11)
plt.ylabel("AUC Value", fontsize=14)
plt.xlabel("Disorder", fontsize=14)
plt.title("Logistic Regression Average AUC Values for Different Main Disorders", fontsize=15)

plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### This creates a line plot for the average AUC values of logistic regression for each specific disorder, for both the models trained on PCA and without. The standard deviations of the AUCs are the error bars.

# %%
disorders = splg.columns[1:]  # skip the first column
x = np.arange(len(disorders))

# Extract rows
without_pca = splg.iloc[0, 1:].astype(float)
with_pca = splg.iloc[1, 1:].astype(float)
std_without = splg.iloc[2, 1:].astype(float)
std_with = splg.iloc[3, 1:].astype(float)

# Plot with error bars
plt.figure(figsize=(10, 6))
plt.errorbar(x, without_pca, yerr=std_without, label='Without PCA', 
             marker='o', capsize=5, linestyle='-', color='darkred')
plt.errorbar(x, with_pca, yerr=std_with, label='With PCA', 
             marker='o', capsize=5, linestyle='-', color='midnightblue')

# Final touches
plt.xticks(x, disorders, rotation=45, ha='right', fontsize=11)
plt.ylabel("AUC Value", fontsize=14)
plt.xlabel("Disorder", fontsize=14)
plt.title("Logistic Regression Average AUC Values for Different Specific Disorders", fontsize=15)

plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### The cell below creates a line plot for the average AUC values of each model calculated from all of the main disorders, for both the models trained on PCA and without. The standard deviations of the AUCs are the error bars.

# %%
disorders = model.columns[1:]  # skip the first column
x = np.arange(len(disorders))

# Extract rows
without_pca = model.iloc[0, 1:].astype(float)
with_pca = model.iloc[1, 1:].astype(float)
std_without = model.iloc[2, 1:].astype(float)
std_with = model.iloc[3, 1:].astype(float)

# Plot with error bars
plt.figure(figsize=(10, 6))
plt.errorbar(x, without_pca, yerr=std_without, label='Without PCA', 
             marker='o', capsize=5, linestyle='-', color='darkred')
plt.errorbar(x, with_pca, yerr=std_with, label='With PCA', 
             marker='o', capsize=5, linestyle='-', color='midnightblue')

# Final touches
plt.xticks(x, disorders, rotation=45, ha='right', fontsize=11)
plt.ylabel("AUC Value", fontsize=14)
plt.xlabel("Algorithm", fontsize=14)
plt.title("Average AUC Values of Algorithms for All Main Disorders", fontsize=15)
plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### The cell below creates a line plot for the average AUC values of each model calculated from all of the specific disorders, for both the models trained on PCA and without. The standard deviations of the AUCs are the error bars.

# %%
disorders = sp.columns[1:]  
x = np.arange(len(disorders))

# Extract rows
without_pca = sp.iloc[0, 1:].astype(float)
with_pca = sp.iloc[1, 1:].astype(float)
std_without = sp.iloc[2, 1:].astype(float)
std_with = sp.iloc[3, 1:].astype(float)

# Plot with error bars
plt.figure(figsize=(10, 6))
plt.errorbar(x, without_pca, yerr=std_without, label='Without PCA', 
             marker='o', capsize=5, linestyle='-', color='darkred')
plt.errorbar(x, with_pca, yerr=std_with, label='With PCA', 
             marker='o', capsize=5, linestyle='-', color='midnightblue')

# Final touches
plt.xticks(x, disorders, rotation=45, ha='right', fontsize=11)
plt.ylabel("AUC Value", fontsize=14)
plt.xlabel("Algorithm", fontsize=14)
plt.title("Average AUC Values of Algorithms for All Specific Disorders", fontsize=15)
plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## AUC for Different Features

# %% [markdown]
# #### This plots a line graph of the average AUC values of logistic regression for each main disorder, for both the models trained on data with Age, Education, and IQ as features, and without. The standard deviations of the AUCs are the error bars.

# %%
disorders = AEI.columns[1:]  # skip the first column
x = np.arange(len(disorders))

# Extract rows
without_pca = AEI.iloc[0, 1:].astype(float)
with_pca = AEI.iloc[1, 1:].astype(float)
std_without = AEI.iloc[2, 1:].astype(float)
std_with = AEI.iloc[3, 1:].astype(float)

# Plot with error bars
plt.figure(figsize=(10, 6))
plt.errorbar(x, without_pca, yerr=std_without, label='Without Age, Education, IQ', 
             marker='o', capsize=5, linestyle='-', color='darkred')
plt.errorbar(x, with_pca, yerr=std_with, label='With Age, Education, IQ', 
             marker='o', capsize=5, linestyle='-', color='midnightblue')

# Final touches
plt.xticks(x, disorders, rotation=45, ha='right', fontsize=11)
plt.ylabel("AUC Value", fontsize=14)
plt.xlabel("Disorder", fontsize=14)
plt.title("Average Logistic Regression AUC Values for Different Main Disorders", fontsize=15)
plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()
